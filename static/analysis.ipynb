# %%
import pandas as pd
df = pd.read_csv('data_full.csv')
df
# Out:
#         id                         sitename        publishedtime  \
# 0    20869  News Channel 5 Nashville (WTVF)  2025-02-24 00:00:00
# 1    19399    Otago Daily Times Online News  2024-11-11 00:00:00
# 2    19402                     9news.com.au  2024-11-12 00:00:00
# 3    19418    Otago Daily Times Online News  2024-11-12 00:00:00
# 4    19403                     9news.com.au  2024-11-10 00:00:00
# ..     ...                              ...                  ...
# 528  16337                        fox17.com  2018-09-19 00:00:00
# 529  13822                    pottsmerc.com  2012-03-06 00:00:00
# 530   6532                   theargus.co.uk  2020-10-09 00:00:00
# 531   6587                   theargus.co.uk  2020-10-21 00:00:00
# 532   6732                walesonline.co.uk  0000-00-00 00:00:00
#
#                                                    url  \
# 0    https://www.newschannel5.com/news/mnpd-searchi...
# 1    https://www.odt.co.nz/news/australia/one-dead-...
# ...

# %%
df = df.iloc[0:10]

# %%
df.to_csv('data.csv', index=False)
